# %%
from citipy import citipy
import pandas as pd
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime
import time

# %%
# Create a new set of 2,000 random latitudes and longitudes

lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-90, 90, size=2000)

# Next is to zip lats and longs as pairs
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Unzip and put in a list / set as coordinates variable
coordinates = list(lat_lngs)

# %%
# Create my blank cities list
cities = []

# GET NEAREST CITIES USING CITYPY MODULE (DELIVERABLE 1)
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

# %%
# Get/Confirm length of cities in list
len(cities)
# Out:
# 780

# %%
# PEFORM AN API CALL WITH THE OPENWEATHERMAP (DELIVERABLE 1)

## Set up URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# RETRIEVE INFORMATION FROM API CALL (DELIVERABLE 1)

# Create an empty list to hold weather data (Referenced class exercise and modules)

city_data = []

# Print the beginning of the logging
print("BEGINNING DATA RETRIEVAL     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list (Use Enumerate)
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"PROCESSING RECORD {record_count} OF SET {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run API request for each of the cities
        # Parse the JSON and Retrieve Data
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city info into city_data list created earlier
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Country": city_country})
        
# If an error is experienced then skip the city
    except:
        print("CITY NOT FOUND! SKIPPING...")
        pass
# Indicate that Data Retrieval is complete
print("-----------------------------")
print("DATA RETRIEVAL COMPLETE      ")
print("-----------------------------")
# Out:
# BEGINNING DATA RETRIEVAL
# -----------------------------
# PROCESSING RECORD 1 OF SET 1 | cape town
# PROCESSING RECORD 2 OF SET 1 | bredasdorp
# PROCESSING RECORD 3 OF SET 1 | busselton
# PROCESSING RECORD 4 OF SET 1 | diego de almagro
# PROCESSING RECORD 5 OF SET 1 | paamiut
# PROCESSING RECORD 6 OF SET 1 | illoqqortoormiut
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 7 OF SET 1 | coihaique
# PROCESSING RECORD 8 OF SET 1 | kibala
# PROCESSING RECORD 9 OF SET 1 | tumannyy
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 10 OF SET 1 | aracaju
# PROCESSING RECORD 11 OF SET 1 | antofagasta
# PROCESSING RECORD 12 OF SET 1 | takoradi
# PROCESSING RECORD 13 OF SET 1 | jamestown
# PROCESSING RECORD 14 OF SET 1 | bandarbeyla
# PROCESSING RECORD 15 OF SET 1 | floro
# PROCESSING RECORD 16 OF SET 1 | castro
# PROCESSING RECORD 17 OF SET 1 | itarema
# PROCESSING RECORD 18 OF SET 1 | dikson
# PROCESSING RECORD 19 OF SET 1 | hun
# PROCESSING RECORD 20 OF SET 1 | nanyamba
# PROCESSING RECORD 21 OF SET 1 | korla
# PROCESSING RECORD 22 OF SET 1 | taolanaro
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 23 OF SET 1 | qaanaaq
# PROCESSING RECORD 24 OF SET 1 | storforshei
# PROCESSING RECORD 25 OF SET 1 | caraz
# PROCESSING RECORD 26 OF SET 1 | monrovia
# PROCESSING RECORD 27 OF SET 1 | namibe
# PROCESSING RECORD 28 OF SET 1 | vila velha
# PROCESSING RECORD 29 OF SET 1 | verkh-suetka
# PROCESSING RECORD 30 OF SET 1 | hithadhoo
# PROCESSING RECORD 31 OF SET 1 | margate
# PROCESSING RECORD 32 OF SET 1 | belushya guba
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 33 OF SET 1 | presidente epitacio
# PROCESSING RECORD 34 OF SET 1 | arraial do cabo
# PROCESSING RECORD 35 OF SET 1 | pangnirtung
# PROCESSING RECORD 36 OF SET 1 | amderma
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 37 OF SET 1 | koson
# PROCESSING RECORD 38 OF SET 1 | ponta do sol
# PROCESSING RECORD 39 OF SET 1 | mweka
# PROCESSING RECORD 40 OF SET 1 | tsienyane
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 41 OF SET 1 | bubaque
# PROCESSING RECORD 42 OF SET 1 | antalaha
# PROCESSING RECORD 43 OF SET 1 | port elizabeth
# PROCESSING RECORD 44 OF SET 1 | hermanus
# PROCESSING RECORD 45 OF SET 1 | riyadh
# PROCESSING RECORD 46 OF SET 1 | mount pleasant
# PROCESSING RECORD 47 OF SET 1 | ardino
# PROCESSING RECORD 48 OF SET 1 | ushuaia
# PROCESSING RECORD 49 OF SET 1 | comodoro rivadavia
# PROCESSING RECORD 50 OF SET 1 | nicoya
# PROCESSING RECORD 1 OF SET 2 | omboue
# PROCESSING RECORD 2 OF SET 2 | upernavik
# PROCESSING RECORD 3 OF SET 2 | ambilobe
# PROCESSING RECORD 4 OF SET 2 | saint-michel-des-saints
# PROCESSING RECORD 5 OF SET 2 | port blair
# PROCESSING RECORD 6 OF SET 2 | port alfred
# PROCESSING RECORD 7 OF SET 2 | bulle
# PROCESSING RECORD 8 OF SET 2 | kruisfontein
# PROCESSING RECORD 9 OF SET 2 | hofn
# PROCESSING RECORD 10 OF SET 2 | tasiilaq
# PROCESSING RECORD 11 OF SET 2 | kokstad
# PROCESSING RECORD 12 OF SET 2 | kudahuvadhoo
# PROCESSING RECORD 13 OF SET 2 | saint george
# PROCESSING RECORD 14 OF SET 2 | barentsburg
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 15 OF SET 2 | georgetown
# PROCESSING RECORD 16 OF SET 2 | kavaratti
# PROCESSING RECORD 17 OF SET 2 | torbay
# PROCESSING RECORD 18 OF SET 2 | mirante do paranapanema
# PROCESSING RECORD 19 OF SET 2 | lebu
# PROCESSING RECORD 20 OF SET 2 | troy
# PROCESSING RECORD 21 OF SET 2 | santiago del estero
# PROCESSING RECORD 22 OF SET 2 | hamilton
# PROCESSING RECORD 23 OF SET 2 | berlevag
# PROCESSING RECORD 24 OF SET 2 | mecca
# PROCESSING RECORD 25 OF SET 2 | kamyshla
# PROCESSING RECORD 26 OF SET 2 | mosquera
# PROCESSING RECORD 27 OF SET 2 | itacoatiara
# PROCESSING RECORD 28 OF SET 2 | adeje
# PROCESSING RECORD 29 OF SET 2 | bonavista
# PROCESSING RECORD 30 OF SET 2 | ponta delgada
# PROCESSING RECORD 31 OF SET 2 | mar del plata
# PROCESSING RECORD 32 OF SET 2 | turkeve
# PROCESSING RECORD 33 OF SET 2 | ribeira grande
# PROCESSING RECORD 34 OF SET 2 | victoria
# PROCESSING RECORD 35 OF SET 2 | mahibadhoo
# PROCESSING RECORD 36 OF SET 2 | tabou
# PROCESSING RECORD 37 OF SET 2 | grand river south east
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 38 OF SET 2 | coquimbo
# PROCESSING RECORD 39 OF SET 2 | sahrak
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 40 OF SET 2 | sambava
# PROCESSING RECORD 41 OF SET 2 | anloga
# PROCESSING RECORD 42 OF SET 2 | torbat-e jam
# PROCESSING RECORD 43 OF SET 2 | mahebourg
# PROCESSING RECORD 44 OF SET 2 | sehithwa
# PROCESSING RECORD 45 OF SET 2 | portobelo
# PROCESSING RECORD 46 OF SET 2 | umzimvubu
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 47 OF SET 2 | saint-philippe
# PROCESSING RECORD 48 OF SET 2 | tucuman
# PROCESSING RECORD 49 OF SET 2 | inirida
# PROCESSING RECORD 50 OF SET 2 | codrington
# PROCESSING RECORD 1 OF SET 3 | gostyn
# PROCESSING RECORD 2 OF SET 3 | chuy
# PROCESSING RECORD 3 OF SET 3 | kijaba
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 4 OF SET 3 | kumluca
# PROCESSING RECORD 5 OF SET 3 | marfino
# PROCESSING RECORD 6 OF SET 3 | cidreira
# PROCESSING RECORD 7 OF SET 3 | skala fourkas
# PROCESSING RECORD 8 OF SET 3 | nanortalik
# PROCESSING RECORD 9 OF SET 3 | kuche
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 10 OF SET 3 | yazman
# PROCESSING RECORD 11 OF SET 3 | punta arenas
# PROCESSING RECORD 12 OF SET 3 | pemba
# PROCESSING RECORD 13 OF SET 3 | souillac
# PROCESSING RECORD 14 OF SET 3 | mykhaylivka
# PROCESSING RECORD 15 OF SET 3 | luanda
# PROCESSING RECORD 16 OF SET 3 | marsa matruh
# PROCESSING RECORD 17 OF SET 3 | marcona
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 18 OF SET 3 | agucadoura
# PROCESSING RECORD 19 OF SET 3 | bereda
# PROCESSING RECORD 20 OF SET 3 | brindisi
# PROCESSING RECORD 21 OF SET 3 | maragogi
# PROCESSING RECORD 22 OF SET 3 | ginda
# PROCESSING RECORD 23 OF SET 3 | plyussa
# PROCESSING RECORD 24 OF SET 3 | armacao dos buzios
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 25 OF SET 3 | balasesti
# PROCESSING RECORD 26 OF SET 3 | novaya ladoga
# PROCESSING RECORD 27 OF SET 3 | camacha
# PROCESSING RECORD 28 OF SET 3 | martigny
# PROCESSING RECORD 29 OF SET 3 | kemijarvi
# PROCESSING RECORD 30 OF SET 3 | havoysund
# PROCESSING RECORD 31 OF SET 3 | nyanza
# PROCESSING RECORD 32 OF SET 3 | east london
# PROCESSING RECORD 33 OF SET 3 | havre-saint-pierre
# PROCESSING RECORD 34 OF SET 3 | ayagoz
# PROCESSING RECORD 35 OF SET 3 | longyearbyen
# PROCESSING RECORD 36 OF SET 3 | correntina
# PROCESSING RECORD 37 OF SET 3 | faya
# PROCESSING RECORD 38 OF SET 3 | iqaluit
# PROCESSING RECORD 39 OF SET 3 | bakchar
# PROCESSING RECORD 40 OF SET 3 | mercedes
# PROCESSING RECORD 41 OF SET 3 | ustye
# PROCESSING RECORD 42 OF SET 3 | kralendijk
# PROCESSING RECORD 43 OF SET 3 | bonthe
# PROCESSING RECORD 44 OF SET 3 | guatire
# PROCESSING RECORD 45 OF SET 3 | dingle
# PROCESSING RECORD 46 OF SET 3 | bertoua
# PROCESSING RECORD 47 OF SET 3 | bilma
# PROCESSING RECORD 48 OF SET 3 | aksu
# PROCESSING RECORD 49 OF SET 3 | westport
# PROCESSING RECORD 50 OF SET 3 | vitre
# PROCESSING RECORD 1 OF SET 4 | abu samrah
# PROCESSING RECORD 2 OF SET 4 | honningsvag
# PROCESSING RECORD 3 OF SET 4 | adrar
# PROCESSING RECORD 4 OF SET 4 | krasnousolskiy
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 5 OF SET 4 | winneba
# PROCESSING RECORD 6 OF SET 4 | suleja
# PROCESSING RECORD 7 OF SET 4 | matadi
# PROCESSING RECORD 8 OF SET 4 | chapais
# PROCESSING RECORD 9 OF SET 4 | sechura
# PROCESSING RECORD 10 OF SET 4 | karamay
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 11 OF SET 4 | alfatar
# PROCESSING RECORD 12 OF SET 4 | zheleznodorozhnyy
# PROCESSING RECORD 13 OF SET 4 | bulawayo
# PROCESSING RECORD 14 OF SET 4 | chilca
# PROCESSING RECORD 15 OF SET 4 | gat
# PROCESSING RECORD 16 OF SET 4 | sangueya
# PROCESSING RECORD 17 OF SET 4 | kutum
# PROCESSING RECORD 18 OF SET 4 | guanica
# PROCESSING RECORD 19 OF SET 4 | vestmannaeyjar
# PROCESSING RECORD 20 OF SET 4 | jaguariaiva
# PROCESSING RECORD 21 OF SET 4 | santiago
# PROCESSING RECORD 22 OF SET 4 | sinnamary
# PROCESSING RECORD 23 OF SET 4 | vila franca do campo
# PROCESSING RECORD 24 OF SET 4 | methana
# PROCESSING RECORD 25 OF SET 4 | saldanha
# PROCESSING RECORD 26 OF SET 4 | borovskoy
# PROCESSING RECORD 27 OF SET 4 | tunduru
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 28 OF SET 4 | ilulissat
# PROCESSING RECORD 29 OF SET 4 | san carlos de bariloche
# PROCESSING RECORD 30 OF SET 4 | tefe
# PROCESSING RECORD 31 OF SET 4 | valparaiso
# PROCESSING RECORD 32 OF SET 4 | ostersund
# PROCESSING RECORD 33 OF SET 4 | kalmar
# PROCESSING RECORD 34 OF SET 4 | pangody
# PROCESSING RECORD 35 OF SET 4 | maloshuyka
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 36 OF SET 4 | nouadhibou
# PROCESSING RECORD 37 OF SET 4 | bluefields
# PROCESSING RECORD 38 OF SET 4 | tsihombe
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 39 OF SET 4 | grand gaube
# PROCESSING RECORD 40 OF SET 4 | suzun
# PROCESSING RECORD 41 OF SET 4 | megion
# PROCESSING RECORD 42 OF SET 4 | batsfjord
# PROCESSING RECORD 43 OF SET 4 | bathsheba
# PROCESSING RECORD 44 OF SET 4 | staraya poltavka
# PROCESSING RECORD 45 OF SET 4 | london
# PROCESSING RECORD 46 OF SET 4 | uwayl
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 47 OF SET 4 | olafsvik
# PROCESSING RECORD 48 OF SET 4 | villarrica
# PROCESSING RECORD 49 OF SET 4 | leh
# PROCESSING RECORD 50 OF SET 4 | pisco
# PROCESSING RECORD 1 OF SET 5 | kharp
# PROCESSING RECORD 2 OF SET 5 | baie-comeau
# PROCESSING RECORD 3 OF SET 5 | znamenskoye
# PROCESSING RECORD 4 OF SET 5 | horta
# PROCESSING RECORD 5 OF SET 5 | sept-iles
# PROCESSING RECORD 6 OF SET 5 | soyo
# PROCESSING RECORD 7 OF SET 5 | mattru
# PROCESSING RECORD 8 OF SET 5 | dubai
# PROCESSING RECORD 9 OF SET 5 | bollnas
# PROCESSING RECORD 10 OF SET 5 | kalmunai
# PROCESSING RECORD 11 OF SET 5 | kamenka
# PROCESSING RECORD 12 OF SET 5 | rehoboth
# PROCESSING RECORD 13 OF SET 5 | ampanihy
# PROCESSING RECORD 14 OF SET 5 | ati
# PROCESSING RECORD 15 OF SET 5 | cururupu
# PROCESSING RECORD 16 OF SET 5 | manakara
# PROCESSING RECORD 17 OF SET 5 | danville
# PROCESSING RECORD 18 OF SET 5 | florina
# PROCESSING RECORD 19 OF SET 5 | mantua
# PROCESSING RECORD 20 OF SET 5 | angra
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 21 OF SET 5 | moyale
# PROCESSING RECORD 22 OF SET 5 | natal
# PROCESSING RECORD 23 OF SET 5 | walvis bay
# PROCESSING RECORD 24 OF SET 5 | sun prairie
# PROCESSING RECORD 25 OF SET 5 | calvia
# PROCESSING RECORD 26 OF SET 5 | atkinson
# PROCESSING RECORD 27 OF SET 5 | la peca
# PROCESSING RECORD 28 OF SET 5 | beira
# PROCESSING RECORD 29 OF SET 5 | ranikhet
# PROCESSING RECORD 30 OF SET 5 | bin qirdan
# PROCESSING RECORD 31 OF SET 5 | prieska
# PROCESSING RECORD 32 OF SET 5 | tarsus
# PROCESSING RECORD 33 OF SET 5 | dera bugti
# PROCESSING RECORD 34 OF SET 5 | putina
# PROCESSING RECORD 35 OF SET 5 | marsh harbour
# PROCESSING RECORD 36 OF SET 5 | belmonte
# PROCESSING RECORD 37 OF SET 5 | sorland
# PROCESSING RECORD 38 OF SET 5 | clyde river
# PROCESSING RECORD 39 OF SET 5 | taoudenni
# PROCESSING RECORD 40 OF SET 5 | geraldton
# PROCESSING RECORD 41 OF SET 5 | cape canaveral
# PROCESSING RECORD 42 OF SET 5 | morros
# PROCESSING RECORD 43 OF SET 5 | cayenne
# PROCESSING RECORD 44 OF SET 5 | talara
# PROCESSING RECORD 45 OF SET 5 | khandbari
# PROCESSING RECORD 46 OF SET 5 | bengkulu
# PROCESSING RECORD 47 OF SET 5 | los llanos de aridane
# PROCESSING RECORD 48 OF SET 5 | senges
# PROCESSING RECORD 49 OF SET 5 | bella union
# PROCESSING RECORD 50 OF SET 5 | port hawkesbury
# PROCESSING RECORD 1 OF SET 6 | touros
# PROCESSING RECORD 2 OF SET 6 | benjamin aceval
# PROCESSING RECORD 3 OF SET 6 | tchollire
# PROCESSING RECORD 4 OF SET 6 | gravdal
# PROCESSING RECORD 5 OF SET 6 | matara
# PROCESSING RECORD 6 OF SET 6 | leningradskiy
# PROCESSING RECORD 7 OF SET 6 | aksarka
# PROCESSING RECORD 8 OF SET 6 | gunzenhausen
# PROCESSING RECORD 9 OF SET 6 | marzuq
# PROCESSING RECORD 10 OF SET 6 | birao
# PROCESSING RECORD 11 OF SET 6 | manaure
# PROCESSING RECORD 12 OF SET 6 | kembe
# PROCESSING RECORD 13 OF SET 6 | andros town
# PROCESSING RECORD 14 OF SET 6 | virginia beach
# PROCESSING RECORD 15 OF SET 6 | humberto de campos
# PROCESSING RECORD 16 OF SET 6 | togul
# PROCESSING RECORD 17 OF SET 6 | rio gallegos
# PROCESSING RECORD 18 OF SET 6 | illapel
# PROCESSING RECORD 19 OF SET 6 | muros
# PROCESSING RECORD 20 OF SET 6 | dovers
# PROCESSING RECORD 21 OF SET 6 | talnakh
# PROCESSING RECORD 22 OF SET 6 | ponnani
# PROCESSING RECORD 23 OF SET 6 | isabela
# PROCESSING RECORD 24 OF SET 6 | emba
# PROCESSING RECORD 25 OF SET 6 | malwan
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 26 OF SET 6 | sao joao da barra
# PROCESSING RECORD 27 OF SET 6 | santa cruz
# PROCESSING RECORD 28 OF SET 6 | attawapiskat
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 29 OF SET 6 | morondava
# PROCESSING RECORD 30 OF SET 6 | bafq
# PROCESSING RECORD 31 OF SET 6 | bastia
# PROCESSING RECORD 32 OF SET 6 | bargal
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 33 OF SET 6 | shar
# PROCESSING RECORD 34 OF SET 6 | madzhalis
# PROCESSING RECORD 35 OF SET 6 | arlit
# PROCESSING RECORD 36 OF SET 6 | khuzdar
# PROCESSING RECORD 37 OF SET 6 | novoagansk
# PROCESSING RECORD 38 OF SET 6 | calderitas
# PROCESSING RECORD 39 OF SET 6 | quatre cocos
# PROCESSING RECORD 40 OF SET 6 | shrigonda
# PROCESSING RECORD 41 OF SET 6 | liverpool
# PROCESSING RECORD 42 OF SET 6 | palmares do sul
# PROCESSING RECORD 43 OF SET 6 | san andres
# PROCESSING RECORD 44 OF SET 6 | chadiza
# PROCESSING RECORD 45 OF SET 6 | zapolyarnyy
# PROCESSING RECORD 46 OF SET 6 | klaksvik
# PROCESSING RECORD 47 OF SET 6 | alta gracia
# PROCESSING RECORD 48 OF SET 6 | duku
# PROCESSING RECORD 49 OF SET 6 | selty
# PROCESSING RECORD 50 OF SET 6 | giresun
# PROCESSING RECORD 1 OF SET 7 | lagoa
# PROCESSING RECORD 2 OF SET 7 | puerto narino
# PROCESSING RECORD 3 OF SET 7 | evans
# PROCESSING RECORD 4 OF SET 7 | mahbubabad
# PROCESSING RECORD 5 OF SET 7 | dudinka
# PROCESSING RECORD 6 OF SET 7 | ulagan
# PROCESSING RECORD 7 OF SET 7 | sao gabriel da cachoeira
# PROCESSING RECORD 8 OF SET 7 | calabozo
# PROCESSING RECORD 9 OF SET 7 | chicama
# PROCESSING RECORD 10 OF SET 7 | nuuk
# PROCESSING RECORD 11 OF SET 7 | nevsehir
# PROCESSING RECORD 12 OF SET 7 | polovinnoye
# PROCESSING RECORD 13 OF SET 7 | kathmandu
# PROCESSING RECORD 14 OF SET 7 | pizarro
# PROCESSING RECORD 15 OF SET 7 | lunino
# PROCESSING RECORD 16 OF SET 7 | straumen
# PROCESSING RECORD 17 OF SET 7 | lubao
# PROCESSING RECORD 18 OF SET 7 | mayumba
# PROCESSING RECORD 19 OF SET 7 | sagua la grande
# PROCESSING RECORD 20 OF SET 7 | esmeraldas
# PROCESSING RECORD 21 OF SET 7 | porbandar
# PROCESSING RECORD 22 OF SET 7 | afsin
# PROCESSING RECORD 23 OF SET 7 | jhinjhana
# PROCESSING RECORD 24 OF SET 7 | reyes
# PROCESSING RECORD 25 OF SET 7 | umm lajj
# PROCESSING RECORD 26 OF SET 7 | dalbandin
# PROCESSING RECORD 27 OF SET 7 | veraval
# PROCESSING RECORD 28 OF SET 7 | surt
# PROCESSING RECORD 29 OF SET 7 | hambantota
# PROCESSING RECORD 30 OF SET 7 | mahadday weyne
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 31 OF SET 7 | murgab
# PROCESSING RECORD 32 OF SET 7 | salinas
# PROCESSING RECORD 33 OF SET 7 | leo
# PROCESSING RECORD 34 OF SET 7 | saint anthony
# PROCESSING RECORD 35 OF SET 7 | trairi
# PROCESSING RECORD 36 OF SET 7 | awjilah
# PROCESSING RECORD 37 OF SET 7 | walker
# PROCESSING RECORD 38 OF SET 7 | selu
# PROCESSING RECORD 39 OF SET 7 | saint-pierre
# PROCESSING RECORD 40 OF SET 7 | wanderlandia
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 41 OF SET 7 | luderitz
# PROCESSING RECORD 42 OF SET 7 | cumaribo
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 43 OF SET 7 | staroutkinsk
# PROCESSING RECORD 44 OF SET 7 | yarada
# PROCESSING RECORD 45 OF SET 7 | angol
# PROCESSING RECORD 46 OF SET 7 | bambous virieux
# PROCESSING RECORD 47 OF SET 7 | mount darwin
# PROCESSING RECORD 48 OF SET 7 | talcahuano
# PROCESSING RECORD 49 OF SET 7 | jamsa
# PROCESSING RECORD 50 OF SET 7 | pontal do parana
# PROCESSING RECORD 1 OF SET 8 | pedernales
# PROCESSING RECORD 2 OF SET 8 | mao
# PROCESSING RECORD 3 OF SET 8 | naron
# PROCESSING RECORD 4 OF SET 8 | libreville
# PROCESSING RECORD 5 OF SET 8 | sovetskiy
# PROCESSING RECORD 6 OF SET 8 | svetlyy
# PROCESSING RECORD 7 OF SET 8 | krivosheino
# PROCESSING RECORD 8 OF SET 8 | mahalapye
# PROCESSING RECORD 9 OF SET 8 | killybegs
# PROCESSING RECORD 10 OF SET 8 | oussouye
# PROCESSING RECORD 11 OF SET 8 | mogadishu
# PROCESSING RECORD 12 OF SET 8 | puerto asis
# PROCESSING RECORD 13 OF SET 8 | lethem
# PROCESSING RECORD 14 OF SET 8 | alghero
# PROCESSING RECORD 15 OF SET 8 | olinda
# PROCESSING RECORD 16 OF SET 8 | shcherbinka
# PROCESSING RECORD 17 OF SET 8 | gamba
# PROCESSING RECORD 18 OF SET 8 | aripuana
# PROCESSING RECORD 19 OF SET 8 | cockburn town
# PROCESSING RECORD 20 OF SET 8 | ostrovnoy
# PROCESSING RECORD 21 OF SET 8 | muisne
# PROCESSING RECORD 22 OF SET 8 | rawson
# PROCESSING RECORD 23 OF SET 8 | bilara
# PROCESSING RECORD 24 OF SET 8 | muborak
# PROCESSING RECORD 25 OF SET 8 | scottsburgh
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 26 OF SET 8 | gap
# PROCESSING RECORD 27 OF SET 8 | richards bay
# PROCESSING RECORD 28 OF SET 8 | angoche
# PROCESSING RECORD 29 OF SET 8 | vestmanna
# PROCESSING RECORD 30 OF SET 8 | coruripe
# PROCESSING RECORD 31 OF SET 8 | nouakchott
# PROCESSING RECORD 32 OF SET 8 | lewisporte
# PROCESSING RECORD 33 OF SET 8 | piranhas
# PROCESSING RECORD 34 OF SET 8 | bodden town
# PROCESSING RECORD 35 OF SET 8 | ust-kulom
# PROCESSING RECORD 36 OF SET 8 | bay roberts
# PROCESSING RECORD 37 OF SET 8 | port-cartier
# PROCESSING RECORD 38 OF SET 8 | brasilia de minas
# PROCESSING RECORD 39 OF SET 8 | goderich
# PROCESSING RECORD 40 OF SET 8 | ayaviri
# PROCESSING RECORD 41 OF SET 8 | salalah
# PROCESSING RECORD 42 OF SET 8 | novooleksiyivka
# PROCESSING RECORD 43 OF SET 8 | grindavik
# PROCESSING RECORD 44 OF SET 8 | teguise
# PROCESSING RECORD 45 OF SET 8 | naftah
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 46 OF SET 8 | zabol
# PROCESSING RECORD 47 OF SET 8 | road town
# PROCESSING RECORD 48 OF SET 8 | yazd
# PROCESSING RECORD 49 OF SET 8 | biled
# PROCESSING RECORD 50 OF SET 8 | point pedro
# PROCESSING RECORD 1 OF SET 9 | huarmey
# PROCESSING RECORD 2 OF SET 9 | san vicente
# PROCESSING RECORD 3 OF SET 9 | ewo
# PROCESSING RECORD 4 OF SET 9 | finnentrop
# PROCESSING RECORD 5 OF SET 9 | hounde
# PROCESSING RECORD 6 OF SET 9 | opuwo
# PROCESSING RECORD 7 OF SET 9 | salinopolis
# PROCESSING RECORD 8 OF SET 9 | robertsport
# PROCESSING RECORD 9 OF SET 9 | beloha
# PROCESSING RECORD 10 OF SET 9 | bafoulabe
# PROCESSING RECORD 11 OF SET 9 | iranshahr
# PROCESSING RECORD 12 OF SET 9 | solovetskiy
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 13 OF SET 9 | karakendzha
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 14 OF SET 9 | nurota
# PROCESSING RECORD 15 OF SET 9 | praia
# PROCESSING RECORD 16 OF SET 9 | kachiry
# PROCESSING RECORD 17 OF SET 9 | grand-lahou
# PROCESSING RECORD 18 OF SET 9 | la palma
# PROCESSING RECORD 19 OF SET 9 | maues
# PROCESSING RECORD 20 OF SET 9 | isiro
# PROCESSING RECORD 21 OF SET 9 | sembe
# PROCESSING RECORD 22 OF SET 9 | sinazongwe
# PROCESSING RECORD 23 OF SET 9 | srivardhan
# PROCESSING RECORD 24 OF SET 9 | caravelas
# PROCESSING RECORD 25 OF SET 9 | porto novo
# PROCESSING RECORD 26 OF SET 9 | gornopravdinsk
# PROCESSING RECORD 27 OF SET 9 | oranjemund
# PROCESSING RECORD 28 OF SET 9 | albany
# PROCESSING RECORD 29 OF SET 9 | jalalpur jattan
# PROCESSING RECORD 30 OF SET 9 | tibati
# PROCESSING RECORD 31 OF SET 9 | kabare
# PROCESSING RECORD 32 OF SET 9 | haapsalu
# PROCESSING RECORD 33 OF SET 9 | brandenburg
# PROCESSING RECORD 34 OF SET 9 | nueva guinea
# PROCESSING RECORD 35 OF SET 9 | zhezkazgan
# PROCESSING RECORD 36 OF SET 9 | narsaq
# PROCESSING RECORD 37 OF SET 9 | luwingu
# PROCESSING RECORD 38 OF SET 9 | barra do corda
# PROCESSING RECORD 39 OF SET 9 | koungou
# PROCESSING RECORD 40 OF SET 9 | kayes
# PROCESSING RECORD 41 OF SET 9 | bagua grande
# PROCESSING RECORD 42 OF SET 9 | ibi
# PROCESSING RECORD 43 OF SET 9 | springfield
# PROCESSING RECORD 44 OF SET 9 | viedma
# PROCESSING RECORD 45 OF SET 9 | nawabganj
# PROCESSING RECORD 46 OF SET 9 | marinette
# PROCESSING RECORD 47 OF SET 9 | priiskovyy
# PROCESSING RECORD 48 OF SET 9 | sawakin
# PROCESSING RECORD 49 OF SET 9 | krasnyy yar
# PROCESSING RECORD 50 OF SET 9 | abancay
# PROCESSING RECORD 1 OF SET 10 | wattegama
# PROCESSING RECORD 2 OF SET 10 | khash
# PROCESSING RECORD 3 OF SET 10 | lunenburg
# PROCESSING RECORD 4 OF SET 10 | tsumeb
# PROCESSING RECORD 5 OF SET 10 | cuamba
# PROCESSING RECORD 6 OF SET 10 | mrirt
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 7 OF SET 10 | medea
# PROCESSING RECORD 8 OF SET 10 | ler
# PROCESSING RECORD 9 OF SET 10 | ambodifototra
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 10 OF SET 10 | banes
# PROCESSING RECORD 11 OF SET 10 | souris
# PROCESSING RECORD 12 OF SET 10 | santa isabel
# PROCESSING RECORD 13 OF SET 10 | dwarka
# PROCESSING RECORD 14 OF SET 10 | husavik
# PROCESSING RECORD 15 OF SET 10 | biograd na moru
# PROCESSING RECORD 16 OF SET 10 | bolton
# PROCESSING RECORD 17 OF SET 10 | porto seguro
# PROCESSING RECORD 18 OF SET 10 | santa fe
# PROCESSING RECORD 19 OF SET 10 | radviliskis
# PROCESSING RECORD 20 OF SET 10 | qaqortoq
# PROCESSING RECORD 21 OF SET 10 | pindi gheb
# PROCESSING RECORD 22 OF SET 10 | dubrovnik
# PROCESSING RECORD 23 OF SET 10 | izvoarele sucevei
# PROCESSING RECORD 24 OF SET 10 | ouadda
# PROCESSING RECORD 25 OF SET 10 | the valley
# PROCESSING RECORD 26 OF SET 10 | ust-tsilma
# PROCESSING RECORD 27 OF SET 10 | san francisco
# PROCESSING RECORD 28 OF SET 10 | praia da vitoria
# PROCESSING RECORD 29 OF SET 10 | dilla
# PROCESSING RECORD 30 OF SET 10 | pokaran
# PROCESSING RECORD 31 OF SET 10 | bourges
# PROCESSING RECORD 32 OF SET 10 | kiruna
# PROCESSING RECORD 33 OF SET 10 | jackson
# PROCESSING RECORD 34 OF SET 10 | barzas
# PROCESSING RECORD 35 OF SET 10 | atar
# PROCESSING RECORD 36 OF SET 10 | goundam
# PROCESSING RECORD 37 OF SET 10 | padang
# PROCESSING RECORD 38 OF SET 10 | bahadurgarh
# PROCESSING RECORD 39 OF SET 10 | kidal
# PROCESSING RECORD 40 OF SET 10 | conceicao da barra
# PROCESSING RECORD 41 OF SET 10 | kodoli
# PROCESSING RECORD 42 OF SET 10 | vardo
# PROCESSING RECORD 43 OF SET 10 | halifax
# PROCESSING RECORD 44 OF SET 10 | tiruttani
# PROCESSING RECORD 45 OF SET 10 | fecamp
# PROCESSING RECORD 46 OF SET 10 | mitsamiouli
# PROCESSING RECORD 47 OF SET 10 | bani
# PROCESSING RECORD 48 OF SET 10 | tocopilla
# PROCESSING RECORD 49 OF SET 10 | paradwip
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 50 OF SET 10 | kusa
# PROCESSING RECORD 1 OF SET 11 | tuytepa
# PROCESSING RECORD 2 OF SET 11 | komyshnya
# PROCESSING RECORD 3 OF SET 11 | kozhva
# PROCESSING RECORD 4 OF SET 11 | saint-augustin
# PROCESSING RECORD 5 OF SET 11 | rayachoti
# PROCESSING RECORD 6 OF SET 11 | axim
# PROCESSING RECORD 7 OF SET 11 | montenegro
# PROCESSING RECORD 8 OF SET 11 | tomsani
# PROCESSING RECORD 9 OF SET 11 | chatrapur
# PROCESSING RECORD 10 OF SET 11 | tiznit
# PROCESSING RECORD 11 OF SET 11 | buchanan
# PROCESSING RECORD 12 OF SET 11 | banapur
# PROCESSING RECORD 13 OF SET 11 | sur
# PROCESSING RECORD 14 OF SET 11 | acarau
# PROCESSING RECORD 15 OF SET 11 | svetlogorsk
# PROCESSING RECORD 16 OF SET 11 | ancud
# PROCESSING RECORD 17 OF SET 11 | laguna
# PROCESSING RECORD 18 OF SET 11 | yambio
# PROCESSING RECORD 19 OF SET 11 | whitehaven
# PROCESSING RECORD 20 OF SET 11 | wilson
# PROCESSING RECORD 21 OF SET 11 | lakselv
# PROCESSING RECORD 22 OF SET 11 | karpuninskiy
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 23 OF SET 11 | araouane
# PROCESSING RECORD 24 OF SET 11 | mutis
# PROCESSING RECORD 25 OF SET 11 | tonantins
# PROCESSING RECORD 26 OF SET 11 | orgun
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 27 OF SET 11 | carutapera
# PROCESSING RECORD 28 OF SET 11 | rocha
# PROCESSING RECORD 29 OF SET 11 | harper
# PROCESSING RECORD 30 OF SET 11 | kankon
# PROCESSING RECORD 31 OF SET 11 | ylojarvi
# PROCESSING RECORD 32 OF SET 11 | lasa
# PROCESSING RECORD 33 OF SET 11 | jacobina
# PROCESSING RECORD 34 OF SET 11 | ilam
# PROCESSING RECORD 35 OF SET 11 | severnyy
# PROCESSING RECORD 36 OF SET 11 | raudeberg
# PROCESSING RECORD 37 OF SET 11 | bulancak
# PROCESSING RECORD 38 OF SET 11 | narkevychi
# PROCESSING RECORD 39 OF SET 11 | kulhudhuffushi
# PROCESSING RECORD 40 OF SET 11 | hobyo
# PROCESSING RECORD 41 OF SET 11 | vuktyl
# PROCESSING RECORD 42 OF SET 11 | damaturu
# PROCESSING RECORD 43 OF SET 11 | birnin kebbi
# PROCESSING RECORD 44 OF SET 11 | shelburne
# PROCESSING RECORD 45 OF SET 11 | aflu
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 46 OF SET 11 | banfora
# PROCESSING RECORD 47 OF SET 11 | borova
# PROCESSING RECORD 48 OF SET 11 | meulaboh
# PROCESSING RECORD 49 OF SET 11 | morant bay
# PROCESSING RECORD 50 OF SET 11 | nikita
# PROCESSING RECORD 1 OF SET 12 | nacala
# PROCESSING RECORD 2 OF SET 12 | novovarshavka
# PROCESSING RECORD 3 OF SET 12 | bosaso
# PROCESSING RECORD 4 OF SET 12 | mana
# PROCESSING RECORD 5 OF SET 12 | montemor-o-novo
# PROCESSING RECORD 6 OF SET 12 | vigrestad
# PROCESSING RECORD 7 OF SET 12 | uvinza
# PROCESSING RECORD 8 OF SET 12 | barra patuca
# PROCESSING RECORD 9 OF SET 12 | moose factory
# PROCESSING RECORD 10 OF SET 12 | knysna
# PROCESSING RECORD 11 OF SET 12 | puerto ayacucho
# PROCESSING RECORD 12 OF SET 12 | mbale
# PROCESSING RECORD 13 OF SET 12 | ambovombe
# PROCESSING RECORD 14 OF SET 12 | marawi
# PROCESSING RECORD 15 OF SET 12 | carmen
# PROCESSING RECORD 16 OF SET 12 | bur gabo
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 17 OF SET 12 | conde
# PROCESSING RECORD 18 OF SET 12 | yarim
# PROCESSING RECORD 19 OF SET 12 | banda aceh
# PROCESSING RECORD 20 OF SET 12 | kara
# PROCESSING RECORD 21 OF SET 12 | quelimane
# PROCESSING RECORD 22 OF SET 12 | maturin
# PROCESSING RECORD 23 OF SET 12 | thompson
# PROCESSING RECORD 24 OF SET 12 | mimongo
# PROCESSING RECORD 25 OF SET 12 | warangal
# PROCESSING RECORD 26 OF SET 12 | taraz
# PROCESSING RECORD 27 OF SET 12 | zachagansk
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 28 OF SET 12 | rio grande
# PROCESSING RECORD 29 OF SET 12 | utete
# PROCESSING RECORD 30 OF SET 12 | burica
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 31 OF SET 12 | kataysk
# PROCESSING RECORD 32 OF SET 12 | san borja
# PROCESSING RECORD 33 OF SET 12 | garowe
# PROCESSING RECORD 34 OF SET 12 | kaka
# PROCESSING RECORD 35 OF SET 12 | tallahassee
# PROCESSING RECORD 36 OF SET 12 | fredonia
# PROCESSING RECORD 37 OF SET 12 | coihueco
# PROCESSING RECORD 38 OF SET 12 | sabzevar
# PROCESSING RECORD 39 OF SET 12 | kollam
# PROCESSING RECORD 40 OF SET 12 | cocobeach
# PROCESSING RECORD 41 OF SET 12 | melipilla
# PROCESSING RECORD 42 OF SET 12 | conceicao do araguaia
# PROCESSING RECORD 43 OF SET 12 | tazovskiy
# PROCESSING RECORD 44 OF SET 12 | monte cristi
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 45 OF SET 12 | cap malheureux
# PROCESSING RECORD 46 OF SET 12 | yarmouth
# PROCESSING RECORD 47 OF SET 12 | aswan
# PROCESSING RECORD 48 OF SET 12 | denia
# PROCESSING RECORD 49 OF SET 12 | tessalit
# PROCESSING RECORD 50 OF SET 12 | vagur
# PROCESSING RECORD 1 OF SET 13 | saint-joseph
# PROCESSING RECORD 2 OF SET 13 | anaco
# PROCESSING RECORD 3 OF SET 13 | tabora
# PROCESSING RECORD 4 OF SET 13 | kaduy
# PROCESSING RECORD 5 OF SET 13 | san cristobal
# PROCESSING RECORD 6 OF SET 13 | sao filipe
# PROCESSING RECORD 7 OF SET 13 | san ramon
# PROCESSING RECORD 8 OF SET 13 | couvin
# PROCESSING RECORD 9 OF SET 13 | urengoy
# PROCESSING RECORD 10 OF SET 13 | mingaora
# PROCESSING RECORD 11 OF SET 13 | chhabra
# PROCESSING RECORD 12 OF SET 13 | qandala
# PROCESSING RECORD 13 OF SET 13 | moundsville
# PROCESSING RECORD 14 OF SET 13 | norden
# PROCESSING RECORD 15 OF SET 13 | adre
# PROCESSING RECORD 16 OF SET 13 | umuarama
# PROCESSING RECORD 17 OF SET 13 | sisimiut
# PROCESSING RECORD 18 OF SET 13 | angola
# PROCESSING RECORD 19 OF SET 13 | manama
# PROCESSING RECORD 20 OF SET 13 | itaqui
# PROCESSING RECORD 21 OF SET 13 | gwanda
# PROCESSING RECORD 22 OF SET 13 | serebryansk
# PROCESSING RECORD 23 OF SET 13 | bar harbor
# PROCESSING RECORD 24 OF SET 13 | susehri
# PROCESSING RECORD 25 OF SET 13 | rundu
# PROCESSING RECORD 26 OF SET 13 | mirosi
# PROCESSING RECORD 27 OF SET 13 | rosa zarate
# PROCESSING RECORD 28 OF SET 13 | kazalinsk
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 29 OF SET 13 | senanga
# PROCESSING RECORD 30 OF SET 13 | moche
# PROCESSING RECORD 31 OF SET 13 | dujuma
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 32 OF SET 13 | carayao
# PROCESSING RECORD 33 OF SET 13 | bad bevensen
# PROCESSING RECORD 34 OF SET 13 | sofiyivka
# PROCESSING RECORD 35 OF SET 13 | westerland
# PROCESSING RECORD 36 OF SET 13 | manali
# PROCESSING RECORD 37 OF SET 13 | turukhansk
# PROCESSING RECORD 38 OF SET 13 | el retorno
# PROCESSING RECORD 39 OF SET 13 | antigonish
# PROCESSING RECORD 40 OF SET 13 | plean
# PROCESSING RECORD 41 OF SET 13 | la rioja
# PROCESSING RECORD 42 OF SET 13 | monte patria
# PROCESSING RECORD 43 OF SET 13 | chingirlau
# PROCESSING RECORD 44 OF SET 13 | dunmore town
# PROCESSING RECORD 45 OF SET 13 | pervomayskiy
# PROCESSING RECORD 46 OF SET 13 | senno
# PROCESSING RECORD 47 OF SET 13 | zajecar
# PROCESSING RECORD 48 OF SET 13 | krasnovishersk
# PROCESSING RECORD 49 OF SET 13 | penzance
# PROCESSING RECORD 50 OF SET 13 | pitimbu
# PROCESSING RECORD 1 OF SET 14 | wick
# PROCESSING RECORD 2 OF SET 14 | oistins
# PROCESSING RECORD 3 OF SET 14 | tarudant
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 4 OF SET 14 | hennenman
# PROCESSING RECORD 5 OF SET 14 | tir pol
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 6 OF SET 14 | lukulu
# PROCESSING RECORD 7 OF SET 14 | jawhar
# PROCESSING RECORD 8 OF SET 14 | katrineholm
# PROCESSING RECORD 9 OF SET 14 | matagami
# PROCESSING RECORD 10 OF SET 14 | puerto del rosario
# PROCESSING RECORD 11 OF SET 14 | male
# PROCESSING RECORD 12 OF SET 14 | potiskum
# PROCESSING RECORD 13 OF SET 14 | fonte boa
# PROCESSING RECORD 14 OF SET 14 | salym
# PROCESSING RECORD 15 OF SET 14 | santa cruz cabralia
# PROCESSING RECORD 16 OF SET 14 | rabo de peixe
# PROCESSING RECORD 17 OF SET 14 | bembibre
# PROCESSING RECORD 18 OF SET 14 | parabel
# PROCESSING RECORD 19 OF SET 14 | sumbawanga
# PROCESSING RECORD 20 OF SET 14 | progreso
# PROCESSING RECORD 21 OF SET 14 | mushie
# PROCESSING RECORD 22 OF SET 14 | traverse city
# PROCESSING RECORD 23 OF SET 14 | necochea
# PROCESSING RECORD 24 OF SET 14 | sinkat
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 25 OF SET 14 | cartagena
# PROCESSING RECORD 26 OF SET 14 | mtambile
# PROCESSING RECORD 27 OF SET 14 | melfi
# PROCESSING RECORD 28 OF SET 14 | karmana
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 29 OF SET 14 | mehamn
# PROCESSING RECORD 30 OF SET 14 | fort walton beach
# PROCESSING RECORD 31 OF SET 14 | oriximina
# PROCESSING RECORD 32 OF SET 14 | benghazi
# PROCESSING RECORD 33 OF SET 14 | barnstaple
# PROCESSING RECORD 34 OF SET 14 | panjab
# PROCESSING RECORD 35 OF SET 14 | brazzaville
# PROCESSING RECORD 36 OF SET 14 | neuquen
# PROCESSING RECORD 37 OF SET 14 | oia
# PROCESSING RECORD 38 OF SET 14 | pinega
# PROCESSING RECORD 39 OF SET 14 | deder
# PROCESSING RECORD 40 OF SET 14 | clonakilty
# PROCESSING RECORD 41 OF SET 14 | radhanpur
# PROCESSING RECORD 42 OF SET 14 | durusu
# PROCESSING RECORD 43 OF SET 14 | dzhusaly
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 44 OF SET 14 | abiy adi
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 45 OF SET 14 | kassala
# PROCESSING RECORD 46 OF SET 14 | springbok
# PROCESSING RECORD 47 OF SET 14 | baranchinskiy
# PROCESSING RECORD 48 OF SET 14 | santa maria
# PROCESSING RECORD 49 OF SET 14 | wajid
# PROCESSING RECORD 50 OF SET 14 | qurayyat
# PROCESSING RECORD 1 OF SET 15 | acari
# PROCESSING RECORD 2 OF SET 15 | kupino
# PROCESSING RECORD 3 OF SET 15 | kaspiyskiy
# PROCESSING RECORD 4 OF SET 15 | tall kayf
# PROCESSING RECORD 5 OF SET 15 | presidencia roque saenz pena
# PROCESSING RECORD 6 OF SET 15 | dabwali
# PROCESSING RECORD 7 OF SET 15 | vawkavysk
# PROCESSING RECORD 8 OF SET 15 | bagotville
# PROCESSING RECORD 9 OF SET 15 | ibra
# PROCESSING RECORD 10 OF SET 15 | diu
# PROCESSING RECORD 11 OF SET 15 | taylorville
# PROCESSING RECORD 12 OF SET 15 | prainha
# PROCESSING RECORD 13 OF SET 15 | seredka
# PROCESSING RECORD 14 OF SET 15 | ganta
# PROCESSING RECORD 15 OF SET 15 | lephepe
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 16 OF SET 15 | owando
# PROCESSING RECORD 17 OF SET 15 | kismayo
# PROCESSING RECORD 18 OF SET 15 | manaus
# PROCESSING RECORD 19 OF SET 15 | constitucion
# PROCESSING RECORD 20 OF SET 15 | zharkent
# PROCESSING RECORD 21 OF SET 15 | mirnyy
# PROCESSING RECORD 22 OF SET 15 | kjollefjord
# PROCESSING RECORD 23 OF SET 15 | kyrylivka
# PROCESSING RECORD 24 OF SET 15 | maceio
# PROCESSING RECORD 25 OF SET 15 | west lorne
# PROCESSING RECORD 26 OF SET 15 | micheweni
# PROCESSING RECORD 27 OF SET 15 | scarborough
# PROCESSING RECORD 28 OF SET 15 | tigzirt
# PROCESSING RECORD 29 OF SET 15 | khor
# PROCESSING RECORD 30 OF SET 15 | opobo
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 31 OF SET 15 | shubarshi
# PROCESSING RECORD 32 OF SET 15 | tuggurt
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 33 OF SET 15 | eyl
# PROCESSING RECORD 34 OF SET 15 | englewood
# PROCESSING RECORD 35 OF SET 15 | washington
# PROCESSING RECORD 36 OF SET 15 | refojos de basto
# PROCESSING RECORD 37 OF SET 15 | ruwi
# PROCESSING RECORD 38 OF SET 15 | aybak
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 39 OF SET 15 | san joaquin
# PROCESSING RECORD 40 OF SET 15 | port shepstone
# PROCESSING RECORD 41 OF SET 15 | nizwa
# PROCESSING RECORD 42 OF SET 15 | deori khas
# PROCESSING RECORD 43 OF SET 15 | khilchipur
# PROCESSING RECORD 44 OF SET 15 | zaysan
# PROCESSING RECORD 45 OF SET 15 | tres arroyos
# PROCESSING RECORD 46 OF SET 15 | amos
# PROCESSING RECORD 47 OF SET 15 | ostrovskoye
# PROCESSING RECORD 48 OF SET 15 | kholm
# PROCESSING RECORD 49 OF SET 15 | tapes
# PROCESSING RECORD 50 OF SET 15 | higuey
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 1 OF SET 16 | louisbourg
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 2 OF SET 16 | yaguajay
# PROCESSING RECORD 3 OF SET 16 | ritchie
# PROCESSING RECORD 4 OF SET 16 | myra
# PROCESSING RECORD 5 OF SET 16 | andilamena
# PROCESSING RECORD 6 OF SET 16 | chaplygin
# PROCESSING RECORD 7 OF SET 16 | bulaevo
# PROCESSING RECORD 8 OF SET 16 | jalu
# PROCESSING RECORD 9 OF SET 16 | kalundborg
# PROCESSING RECORD 10 OF SET 16 | boa vista
# PROCESSING RECORD 11 OF SET 16 | boden
# PROCESSING RECORD 12 OF SET 16 | lima
# PROCESSING RECORD 13 OF SET 16 | ariquemes
# PROCESSING RECORD 14 OF SET 16 | aubenas
# PROCESSING RECORD 15 OF SET 16 | tonota
# PROCESSING RECORD 16 OF SET 16 | verkhoturye
# PROCESSING RECORD 17 OF SET 16 | upington
# PROCESSING RECORD 18 OF SET 16 | krasnoselkup
# PROCESSING RECORD 19 OF SET 16 | aquin
# PROCESSING RECORD 20 OF SET 16 | san jose de guanipa
# PROCESSING RECORD 21 OF SET 16 | balykshi
# PROCESSING RECORD 22 OF SET 16 | sukhoverkovo
# CITY NOT FOUND! SKIPPING...
# PROCESSING RECORD 23 OF SET 16 | dutse
# PROCESSING RECORD 24 OF SET 16 | kashipur
# PROCESSING RECORD 25 OF SET 16 | upata
# PROCESSING RECORD 26 OF SET 16 | riviere-au-renard
# PROCESSING RECORD 27 OF SET 16 | behbahan
# PROCESSING RECORD 28 OF SET 16 | glace bay
# PROCESSING RECORD 29 OF SET 16 | maiduguri
# PROCESSING RECORD 30 OF SET 16 | nantucket
# -----------------------------
# DATA RETRIEVAL COMPLETE
# -----------------------------

# %%
# ADD THE DATA TO A NEW DATAFRAME (DELIVERABLE 1)
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Cape Town -33.9258   18.4232     74.26        54           0
# 1        Bredasdorp -34.5322   20.0403     61.68        81          13
# 2         Busselton -33.6500  115.3333     60.01        60          96
# 3  Diego De Almagro -26.3667  -70.0500     77.25        18          20
# 4           Paamiut  61.9940  -49.6678     29.17        58           1
# 5         Coihaique -45.5752  -72.0662     50.61        87          75
# 6            Kibala   9.1104   18.3463    103.95        25          20
# 7           Aracaju -10.9111  -37.0717     87.75        66          40
# 8       Antofagasta -23.6500  -70.4000     63.68        68          23
# 9          Takoradi   4.8845   -1.7554     83.88        75          91
#
#    Wind Speed Current Description Country
# 0       14.97           clear sky      ZA
# 1       22.30          few clouds      ZA
# 2        7.23     overcast clouds      AU
# 3        8.46          few clouds      CL
# 4        7.56           clear sky      GL
# 5        6.91       broken clouds      CL
# 6        0.00          few clouds      TD
# 7       12.66    scattered clouds      BR
# 8        8.86          few clouds      CL
# 9       13.62          light rain      GH

# %%
# EXPORT THE DATAFRAME AS WeatherPy_Database.csv INTO THE WEATHERPY_DATABASE FOLDER (DELIVERABLE 1)  

# First we have to create the CSV output file (I HAD TO PASTE THE FULL PATH)
output_data_file = "/Users/jmorales/Desktop/CLASSWORK/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Now we export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
